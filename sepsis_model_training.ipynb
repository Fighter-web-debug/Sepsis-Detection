# %% [markdown]
# <a href="https://colab.research.google.com/github/Fighter-web-debug/Sepsis-Detection/blob/main/sepsis_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.cuda.is_available())       # Should print True
print(torch.cuda.get_device_name(0))   # Should print NVIDIA T4
# Out:
# True
# Tesla T4
